# %% [markdown]
# # Pset on Inference
#
# [Download notebook :fontawesome-solid-download:](../cps_inference.ipynb){: .md-button .md-button--primary download="cps_inference.ipynb"}
#
# Goal of the problem set:
#
#  - understand heteroskedasticity and clustered standard errors
#  - familiarize yourself with `pandas`, grouping and formating
#  - learn about `numba` to accelerate your code for large data-sets
#
# some useful references:
#
#  - [OLS in python](https://www.statsmodels.org/dev/examples/notebooks/generated/ols.html)
#  - [OLS with formulas](https://www.statsmodels.org/devel/example_formulas.html)
#  - [pandas transorm](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transform.html)
#  - [method chaining in pandas](https://tomaugspurger.github.io/method-chaining.html)
#  - [progress bars](https://tqdm.github.io/)
#
# We are going to reproduce an exercise similar to the example for the computation of standard error.  Start by downloading the CPS data from [here](http://cameron.econ.ucdavis.edu/research/cameron_miller_JHR_files%20to%20share.zip).  We first load the needed libraries, my solutions wich are hidden to you and the data.

# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
#from solutions.sol_pset2 import *
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from tqdm import tqdm
# Out:
# /
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_stata("~/Downloads/files to share/CPS_2012_micro.dta")

# %% [markdown]
# Next generate a fictuous policy that you randomly assigned at the state times gender level. Run the regression and report standard errors given by R for one draw of the poilcy.

# %%
np.random.seed(60356548) # I fix the seed to make sure the draws are reproducible

# we draw the policy for each state
fpol = { k:np.random.uniform() > 0.5 for k in np.unique(data['statefip']) }
data['fp'] = data['statefip'].map(fpol)

data
# Out:
#        year statefip  wtsupp age     sex  yrseduc  wage_per_hour    lnwage  \
# 0      2012    Maine  569.43  44  Female     14.0       7.020000  1.948763
# 1      2012    Maine  595.47  25    Male     16.0       2.117143  0.750067
# 2      2012    Maine  635.66  61  Female     16.0      16.672501  2.813761
# 3      2012    Maine  635.66  62    Male     16.0      17.784000  2.878299
# 4      2012    Maine  513.39  25  Female     12.0       9.633000  2.265195
# ...     ...      ...     ...  ..     ...      ...            ...       ...
# 65680  2012   Hawaii  282.87  24    Male     16.0      28.899000  3.363807
# 65681  2012   Hawaii  362.23  49    Male     18.0      18.525000  2.919121
# 65682  2012   Hawaii  362.23  44  Female     20.0      18.525000  2.919121
# 65683  2012   Hawaii  282.87  28    Male     18.0      24.082500  3.181485
# 65684  2012   Hawaii  282.87  28  Female     18.0      11.856000  2.472834
#
#          age2     fp
# 0      1936.0   True
# 1       625.0   True
# 2      3721.0   True
# 3      3844.0   True
# 4       625.0   True
# ...       ...    ...
# 65680   576.0  False
# 65681  2401.0  False
# 65682  1936.0  False
# 65683   784.0  False
# 65684   784.0  False
#
# [65685 rows x 10 columns]

# %% [markdown]
# !!! question "Question 1"
#     As an exercise to get acquainted with pandas, here I would like for you to implement the following procedure:
#
# 1. compute the average wage in each state for each age decile (less than 20, betwen 20 and 30, ...)
# 2. [pivot](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) the table with states in rows and age deciles in columns
# 3. using [pandas styling](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html), I want you to highlight the lowest wage in each age decile and I want you to format the average wage with onely 2 decimal points.

# %%
#Question 1.1 and 1.2: create pivot table with average wage in each state for each age group

data["age"] = data["age"].astype(int)
data["age_grp"] = pd.cut(x=data["age"], bins=[0, 20, 30, 40, 50, 60, 70], labels=['20.0', '30.0', '40.0', '50.0', '60.0', '70.0'])

grouped_data = data.groupby(["statefip", "age_grp"])["wage_per_hour"].mean()
grouped_data = grouped_data.reset_index().pivot("statefip", "age_grp")

#Question 1.3: highlight lowest wage in each age group and reformat decimal points

grouped_data.style.highlight_min(color = "lightgreen", axis=0).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow12_col5 {
#             background-color:  lightgreen;
#         }    #T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow24_col4 {
#             background-color:  lightgreen;
#         }    #T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow26_col0 {
#             background-color:  lightgreen;
#         }    #T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow40_col1 {
#             background-color:  lightgreen;
#         }    #T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow40_col2 {
#             background-color:  lightgreen;
#         }    #T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow40_col3 {
#             background-color:  lightgreen;
#         }</style><table id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=6>wage_per_hour</th>    </tr>    <tr>        <th class="index_name level1" >age_grp</th>        <th class="col_heading level1 col0" >20.0</th>        <th class="col_heading level1 col1" >30.0</th>        <th class="col_heading level1 col2" >40.0</th>        <th class="col_heading level1 col3" >50.0</th>        <th class="col_heading level1 col4" >60.0</th>        <th class="col_heading level1 col5" >70.0</th>    </tr>    <tr>        <th class="index_name level0" >statefip</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row0" class="row_heading level0 row0" >Alabama</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow0_col0" class="data row0 col0" >8.20</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow0_col1" class="data row0 col1" >11.33</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow0_col2" class="data row0 col2" >15.50</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow0_col3" class="data row0 col3" >19.39</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow0_col4" class="data row0 col4" >17.38</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow0_col5" class="data row0 col5" >15.21</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row1" class="row_heading level0 row1" >Alaska</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow1_col0" class="data row1 col0" >8.68</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow1_col1" class="data row1 col1" >14.14</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow1_col2" class="data row1 col2" >19.92</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow1_col3" class="data row1 col3" >19.59</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow1_col4" class="data row1 col4" >20.67</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow1_col5" class="data row1 col5" >20.46</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row2" class="row_heading level0 row2" >Arizona</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow2_col0" class="data row2 col0" >9.76</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow2_col1" class="data row2 col1" >11.97</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow2_col2" class="data row2 col2" >16.55</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow2_col3" class="data row2 col3" >18.63</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow2_col4" class="data row2 col4" >18.46</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow2_col5" class="data row2 col5" >21.30</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row3" class="row_heading level0 row3" >Arkansas</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow3_col0" class="data row3 col0" >6.52</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow3_col1" class="data row3 col1" >12.47</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow3_col2" class="data row3 col2" >14.95</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow3_col3" class="data row3 col3" >17.36</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow3_col4" class="data row3 col4" >16.13</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow3_col5" class="data row3 col5" >14.26</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row4" class="row_heading level0 row4" >California</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow4_col0" class="data row4 col0" >8.52</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow4_col1" class="data row4 col1" >12.82</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow4_col2" class="data row4 col2" >18.98</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow4_col3" class="data row4 col3" >20.55</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow4_col4" class="data row4 col4" >21.52</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow4_col5" class="data row4 col5" >21.34</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row5" class="row_heading level0 row5" >Colorado</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow5_col0" class="data row5 col0" >9.63</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow5_col1" class="data row5 col1" >12.35</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow5_col2" class="data row5 col2" >19.19</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow5_col3" class="data row5 col3" >21.00</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow5_col4" class="data row5 col4" >21.80</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow5_col5" class="data row5 col5" >21.29</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row6" class="row_heading level0 row6" >Connecticut</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow6_col0" class="data row6 col0" >6.79</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow6_col1" class="data row6 col1" >13.29</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow6_col2" class="data row6 col2" >20.98</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow6_col3" class="data row6 col3" >24.64</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow6_col4" class="data row6 col4" >25.11</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow6_col5" class="data row6 col5" >20.69</td>
#             </tr>
#             <tr>
#                         <th id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9elevel0_row7" class="row_heading level0 row7" >Delaware</th>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow7_col0" class="data row7 col0" >6.05</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c4b301a9ed9erow7_col1" class="data row7 col1" >12.61</td>
#                         <td id="T_1b5c6788_1cc1_11eb_9d97_c

# %% [markdown]
# ## A first regression

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

results = smf.ols('lnwage ~ fp', data=data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 lnwage   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     11.53
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           0.000687
# Time:                        22:08:48   Log-Likelihood:                -62336.
# No. Observations:               65685   AIC:                         1.247e+05
# Df Residuals:                   65683   BIC:                         1.247e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.6687      0.003    836.168      0.000       2.662       2.675
# fp[T.True]     0.0168      0.005      3.395      0.001       0.007       0.026
# ==============================================================================
# Omnibus:                        5.904   Durbin-Watson:                   1.582
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                5.915
# Skew:                           0.023   Prob(JB):                       0.0519
# Kurtosis:                       2.992   Cond. No.                         2.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Note We do not control for state specific fixed effect as these would would be perfectly colinear with the policy.
#
# Now this is surprising. We generated `fp` randomly across states, yet we find a **significant effect** of the policy on log wages. To gain understanding on what is happening we will generate our own data in a way where we control exactly what is happening.

# %% [markdown]
# ## IID errors
#
# Let's start by reassuring ourselves. Let's use an IID data generating process (DGP), run the regression and check the significance.
#
#  1. compute the variance of `lnwage` in the sample. This is an estimate of our homoskedastic error.
#  2. simulate a fictuous outcome `y2` simply equal to normal error with the estimated variance, and truly independent across individuals. Use `.assign(y2 = ...)` on the pandas dataFrame.
#  3. regress this outcome `y2` on `fp`, our fictuous policy and collect the coefficient, also save if the coefficient is significant at 5%.
#  4. run steps (2,3) 500 times.
#
# !!! question "Question 2"
#     Follow the previous steps and report how often we would consider teh coefficient on `fp`significant at 5%. You should find something close to 5% and you should feel better about the theory!

# %%
def iid_errors(df, col, simulations = 500):
    '''
    Returns the proportion of simulations where the pvalue is significant.
    '''
    
    sig_coeffs = 0
    error_var = df[col].var()
    
    for i in range(simulations):
        E = error_var*np.random.normal(size=65685)
        df_sim = df.assign(y2 = lambda x: E)
        results_sim = smf.ols('y2 ~ fp', data=df_sim).fit()
        pval = results_sim.pvalues[1]
    
        if pval < 0.05:
            sig_coeffs += 1
        
    return sig_coeffs/simulations

print(iid_errors(data, "lnwage", 500))
# Out:
# 0.052

# %% [markdown]
# About 5% of the simulations had coefficients on fp that were significant at 5%.

# %% [markdown]
# ## Back to using wages in data
#
# We go back and we do the same exercise, only this time we redraw the policy in each replciations and regress the wages on it, and collect the t-stats. We then plot the histogram of the t-stats and compute the probability of rejecting the null that the coefficient on the policy is 0.
#
# !!! question "Question 3"
#     Replicate 500 times the very first regression to recreate an histogram of t-stats similar to the following one. Compute the probability to reject the null of effect and comment on its value given the way you simulated the data (2 sentences max).

# %%
fpol = { k:np.random.uniform() > 0.5 for k in np.unique(data['statefip']) }
data['fp2'] = data['statefip'].map(fpol)
results_sim = smf.ols('lnwage ~ fp2', data=data).fit()

results_sim.tvalues[1]
# Out:
# -8.712744575728458

# %%
def fp_sim(df, col, simulations):
    
    tstats = []
    
    for i in range(simulations):
        fpol = { k:np.random.uniform() > 0.5 for k in np.unique(data['statefip']) }
        df['fp2'] = df['statefip'].map(fpol)
        results_sim = smf.ols('lnwage ~ fp2', data=df).fit()
        tstat = results_sim.tvalues[1]
        tstats.append(tstat)
        
    return tstats

# %%
sim_tstats = fp_sim(data, "lnwage", 500)
plt.hist(sim_tstats)
plt.axvline(1.96,color='red',linestyle=":")
plt.axvline(-1.96,color='red',linestyle=":")

# %%
# Check the probability to reject the null of effect
print((np.abs(sim_tstats)>1.96).mean())
# Out:
# 0.726

# %% [markdown]
# About 75% of the simulations had a t statistic greater than 1.96 or less than -1.96, which means there is about a 75% probability that we would reject the null of the effect. In the random simulation from the previous problem, we would only reject the null of the effect about 5% of the time, which is what we would expect from a 5% significance level. This result is very strange because the fp variable was generated randomly, yet it seems to have a statistically significant effect on the log of wages 75% of the times we run the simulation. This could likely be because there is some correlation between wages within states, so we need to find a way to account for these correlations.

# %% [markdown]
# ## Heteroskedastic errors
#
# Now we want to simulate heteroskedastic robust standard errors which requires us to use some co-variates. We then want to repeat the previous procedure, but we are going to use a different code for simulation and a new test for the significance. `statsmodels` can do that for you using the `cov_type` argument of the `fit` method.
#
# We want to check this by simulating from a model with heteroskedesatic errors. To do so we are going to use linear model for the variance:
#
# $$ y_{i} = 0 + s(x_i) \cdot \epsilon_i$$
#
# We are going to use a linear specification for $s^2(x_i)$.
#
#  1. run the following regression `lnwage ~ yrseduc + age + age^2` to get the $m(x_i) = x_i' \beta$ where the $x_i$ are education, age and age squared.
#  2. extract the residuals $\hat{u}_i$ from the previous regression. Then regress $\hat{u}^2_i$ on `yrseduc + age + age^2`, to get the $s^2(x_i) = x_i' \gamma$ model.
#  2. using $s^2(x_i) = x_i' \gamma$, construct $ y_{i} = 0 + s(x_i) \cdot \epsilon_i$ where $\epsilon_i$ is drawn iid Normal(0,1).
#  5. replicate this 500 times, evaluate the significance of `fp` using heteroskedastic roduct inference by calling `.fit(cov_type='HC0')`, also save without using the robust errors.
#
# !!! question "Question 4"
#     Follow the steps and report the distributions of t-stats, as well as the rejection rates for each of the two variance specifications.

# %%
def heteroskedastic(df, simulations=500):
    
    ols_tstats = []
    ols_het_tstats = []
    
    first_reg = smf.ols('lnwage ~ fp2 + age + age^2', data=df).fit()
    resid = first_reg.resid
    df['sq_resid'] = resid**2

    second_reg = smf.ols('sq_resid ~ yrseduc + age + age^2', data=df).fit()
    s1 = second_reg.fittedvalues
    s2=s1**(1/2)
    
    for i in range(simulations):
        data["yi"]=s2*np.random.normal(size=len(df))

        ols = smf.ols('yi ~ fp', data=data).fit()
        ols_tstats.append(ols.tvalues[1])

        ols_het = smf.ols('yi ~ fp', data=data).fit(cov_type='HC0')
        ols_het_tstats.append(ols_het.tvalues[1])
      
    return ols_tstats, ols_het_tstats

# %%
tstats, het_tstats = heteroskedastic(data, 500)

# %%
plt.hist(tstats)
plt.axvline(1.96,color='red',linestyle=":")
plt.axvline(-1.96,color='red',linestyle=":")
plt.title('Homoskedastic')
# Out:
# Text(0.5, 1.0, 'Homoskedastic')

# %%
plt.hist(het_tstats)
plt.axvline(1.96,color='red',linestyle=":")
plt.axvline(-1.96,color='red',linestyle=":")
plt.title('Heteroskedastic')

plt.show()

# %%
#Rejection rate for homoskedastic errors:
print((np.abs(tstats)>1.96).mean())
# Out:
# 0.052

# %%
#Rejection rate for heteroskedastic errors:
print((np.abs(het_tstats)>1.96).mean())
# Out:
# 0.052

# %% [markdown]
# ## State clustered errors
#
# We are going to simulate corrolated error within state. To do so we continue to draw independent error terms $u_i$ but we add to them a common draw at the state level. In practice you can do that by doing similar to drawing the `fp`. We then create the outcome as
#
# $$y_{ig} = (1-\rho) u_i + \rho v_g $$
#
# Here is a way of doing this:

# %%
rho=0.5
data['u'] = np.random.normal(size=len(data))
data['v'] = data.groupby('statefip')['u'].transform(lambda x : (1-rho)*x.to_numpy() + rho*np.random.normal(size=1))

# %% [markdown]
# !!! question "Question 5"
#     First, explain the `groupby` expression. Next find another way of doing line 2 and 3, but try to minize the number of characters (see [python golfing](https://www.geeksforgeeks.org/code-golfing-in-python/) or more generaly [wikipedia](https://en.wikipedia.org/wiki/Code_golf)).

# %%
#Answer to question 5
data['u'] = np.random.normal(size=len(data))
data['y'] = data.groupby('statefip')['u'].apply(lambda x:x-rho*x+rho*np.random.normal(size=1))

# %% [markdown]
# The groupby expression in Pandas groups data according to different sets of variables. This allows us to split the data into separate groups to summarize, aggregate, or perform computations. In this case, we are grouping the data by state.

# %% [markdown]
# Before we get started estimating the effect of the policy, let's write a function that computes the within state correlation in the error term.
#
# To that end draw 500 pairs of people where the 2 people in a pair belong to the same state. This gives you 2 vector of length 500. Compute the correlation between these 2 vectors. Use the `sample` and `query` methods of `pandas`. Similarly construct a placebo function that just takes random pairs of workers without imposing that they come from the same state.

# %% [markdown]
# !!! question "Question 6"
#     Write your own version of the `tibo_pair_cor` and `tibo_cor_placebo` functions, see what my version delivers:

# %%
#Answer to question 6

def pair_cor(data, simulations=500):
    
    vector1 = []
    vector2 = []
    
    for i in range(simulations):
        first_draw = data.sample()
        first_state = first_draw.iloc[0]["statefip"]
        second_draw = data.query("statefip == @first_state").sample()
        
        first_v = first_draw.iloc[0]["v"]
        second_v = second_draw.iloc[0]["v"]
        
        vector1.append(first_v)
        vector2.append(second_v)
        
    return np.corrcoef(vector1, vector2)[0][1]

def pair_cor_placebo(data, simulations=500):
    
    vector1 = []
    vector2 = []
    
    for i in range(simulations):
        first_draw = data.sample()
        second_draw = data.sample()

        first_v = first_draw.iloc[0]["v"]
        second_v = second_draw.iloc[0]["v"]
        
        vector1.append(first_v)
        vector2.append(second_v)
        
    return np.corrcoef(vector1, vector2)[0][1]

# %%
rho=0.5
data['u'] = np.random.normal(size=len(data))
data['v'] = data.groupby('statefip')['u'].transform(lambda x : (1-rho)*x.to_numpy() + rho*np.random.normal(size=1))

print(pair_cor(data))
print(pair_cor_placebo(data))

rho=0.8
data['u'] = np.random.normal(size=len(data))
data['v'] = data.groupby('statefip')['u'].transform(lambda x : (1-rho)*x.to_numpy() + rho*np.random.normal(size=1))

print(pair_cor(data))
print(pair_cor_placebo(data))
# Out:
# 0.5097328932745633
# -0.006212768299195678
# 0.9344763181865412
# 0.06364725213497532

# %% [markdown]
# We are then going to replicate the data construction 500 times.
#
# !!! question "Question 7"
#     For $\rho=0.2,0.5,0.8$ run 500 replications and report the proportion at each value of $\rho$ for which the coefficient on$\text{fp}$ is significant at 5%. Report the results for three different regression using regular `fit`, using `cov_type='HC0'` and using `cov_type='cluster'`.

# %%
# here is an example of clusetered errors 
rho=0.8
data['u'] = np.random.normal(size=len(data))
data['v'] = data.groupby('statefip')['u'].transform(lambda x : (1-rho)*x.to_numpy() + rho*np.random.normal(size=1))

data['y'] =  data.v
results = smf.ols('y ~ fp', data=data).fit(cov_type='cluster',cov_kwds={"groups":data['statefip']})
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     3.124
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):             0.0833
# Time:                        22:24:50   Log-Likelihood:                -63025.
# No. Observations:               65685   AIC:                         1.261e+05
# Df Residuals:                   65683   BIC:                         1.261e+05
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2977      0.099     -2.994      0.003      -0.493      -0.103
# fp[T.True]     0.3259      0.184      1.767      0.077      -0.035       0.687
# ==============================================================================
# Omnibus:                      377.343   Durbin-Watson:                   0.203
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              407.766
# Skew:                           0.155   Prob(JB):                     2.85e-89
# Kurtosis:                       3.229   Cond. No.                         2.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %%
# and here the regression without clustered standard errors
rho=0.8
data['u'] = np.random.normal(size=len(data))
data['v'] = data.groupby('statefip')['u'].transform(lambda x : (1-rho)*x.to_numpy() + rho*np.random.normal(size=1))

data['y'] =  data.v
results = smf.ols('y ~ fp', data=data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1225.
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):          5.28e-266
# Time:                        22:24:51   Log-Likelihood:                -96357.
# No. Observations:               65685   AIC:                         1.927e+05
# Df Residuals:                   65683   BIC:                         1.927e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2495      0.005    -46.563      0.000      -0.260      -0.239
# fp[T.True]     0.2907      0.008     35.006      0.000       0.274       0.307
# ==============================================================================
# Omnibus:                     1412.388   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1478.529
# Skew:                          -0.358   Prob(JB):                         0.00
# Kurtosis:                       2.831   Cond. No.                         2.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Answer to question 7

def regression_fits(data, rho, simulations = 500):
    tstats = []
    het_tstats = []
    clust_tstats = []
    
    for i in tqdm(range(simulations)):
        data['u'] = np.random.normal(size=len(data))
        data['v'] = data.groupby('statefip')['u'].transform(lambda x : (1-rho)*x.to_numpy() + rho*np.random.normal(size=1))

        results = smf.ols('v ~ fp', data=data).fit()
        het_results = smf.ols('v ~ fp', data=data).fit(cov_type='HC0')
        clust_results = smf.ols('v ~ fp', data=data).fit(cov_type='cluster',cov_kwds={"groups":data['statefip']})
        
        tstats.append(results.tvalues[1])
        het_tstats.append(het_results.tvalues[1])
        clust_tstats.append(clust_results.tvalues[1])
    
    return tstats, het_tstats, clust_tstats

# %%
rho = 0.2
tstats, het_tstats, clust_tstats = regression_fits(data, rho, 500)
print((np.abs(tstats)>1.96).mean())
print((np.abs(het_tstats)>1.96).mean())
print((np.abs(clust_tstats)>1.96).mean())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#
#
#   0%|          | 1/500 [00:01<12:22,  1.49s/it]
#
#
#   0%|          | 2/500 [00:03<12:31,  1.51s/it]
#
#
#   1%|          | 3/500 [00:04<12:16,  1.48s/it]
#
#
#   1%|          | 4/500 [00:05<11:53,  1.44s/it]
#
#
#   1%|          | 5/500 [00:07<11:35,  1.40s/it]
#
#
#   1%|          | 6/500 [00:08<12:00,  1.46s/it]
#
#
#   1%|▏         | 7/500 [00:10<12:25,  1.51s/it]
#
#
#   2%|▏         | 8/500 [00:11<12:00,  1.46s/it]
#
#
#   2%|▏         | 9/500 [00:13<11:54,  1.46s/it]
#
#
#   2%|▏         | 10/500 [00:14<12:30,  1.53s/it]
#
#
#   2%|▏         | 11/500 [00:16<12:03,  1.48s/it]
#
#
#   2%|▏         | 12/500 [00:17<11:51,  1.46s/it]
#
#
#   3%|▎         | 13/500 [00:19<12:04,  1.49s/it]
#
#
#   3%|▎         | 14/500 [00:20<11:57,  1.48s/it]
#
#
#   3%|▎         | 15/500 [00:21<11:41,  1.45s/it]
#
#
#   3%|▎         | 16/500 [00:23<11:32,  1.43s/it]
#
#
#   3%|▎         | 17/500 [00:24<11:24,  1.42s/it]
#
#
#   4%|▎         | 18/500 [00:26<11:32,  1.44s/it]
#
#
#   4%|▍         | 19/500 [00:27<11:17,  1.41s/it]
#
#
#   4%|▍         | 20/500 [00:29<11:14,  1.41s/it]
#
#
#   4%|▍         | 21/500 [00:30<11:06,  1.39s/it]
#
#
#   4%|▍         | 22/500 [00:31<11:04,  1.39s/it]
#
#
#   5%|▍         | 23/500 [00:33<11:19,  1.42s/it]
#
#
#   5%|▍         | 24/500 [00:34<11:19,  1.43s/it]
#
#
#   5%|▌         | 25/500 [00:36<11:13,  1.42s/it]
#
#
#   5%|▌         | 26/500 [00:37<11:34,  1.47s/it]
#
#
#   5%|▌         | 27/500 [00:39<11:17,  1.43s/it]
#
#
#   6%|▌         | 28/500 [00:40<11:14,  1.43s/it]
#
#
#   6%|▌         | 29/500 [00:41<10:53,  1.39s/it]
#
#
#   6%|▌         | 30/500 [00:43<11:30,  1.47s/it]
#
#
#   6%|▌         | 31/500 [00:44<11:40,  1.49s/it]
#
#
#   6%|▋         | 32/500 [00:46<11:41,  1.50s/it]
#
#
#   7%|▋         | 33/500 [00:47<11:18,  1.45s/it]
#
#
#   7%|▋         | 34/500 [00:49<11:01,  1.42s/it]
#
#
#   7%|▋         | 35/500 [00:50<10:46,  1.39s/it]
#
#
#   7%|▋         | 36/500 [00:51<10:49,  1.40s/it]
#
#
#   7%|▋         | 37/500 [00:53<10:34,  1.37s/it]
#
#
#   8%|▊         | 38/500 [00:54<10:31,  1.37s/it]
#
#
#   8%|▊         | 39/500 [00:56<10:44,  1.40s/it]
#
#
#   8%|▊         | 40/500 [00:57<10:47,  1.41s/it]
#
#
#   8%|▊         | 41/500 [00:58<10:41,  1.40s/it]
#
#
#   8%|▊         | 42/500 [01:00<10:44,  1.41s/it]
#
#
#   9%|▊         | 43/500 [01:01<10:29,  1.38s/it]
#
#
#   9%|▉         | 44/500 [01:02<10:15,  1.35s/it]
#
#
#   9%|▉         | 45/500 [01:04<10:11,  1.34s/it]
#
#
#   9%|▉         | 46/500 [01:05<10:12,  1.35s/it]
#
#
#   9%|▉         | 47/500 [01:06<10:24,  1.38s/it]
#
#
#  10%|▉         | 48/500 [01:08<10:06,  1.34s/it]
#
#
#  10%|▉         | 49/500 [01:09<10:00,  1.33s/it]
#
#
#  10%|█         | 50/500 [01:10<09:53,  1.32s/it]
#
#
#  10%|█         | 51/500 [01:12<09:49,  1.31s/it]
#
#
#  10%|█         | 52/500 [01:13<09:45,  1.31s/it]
#
#
#  11%|█         | 53/500 [01:14<09:43,  1.31s/it]
#
#
#  11%|█         | 54/500 [01:16<09:58,  1.34s/it]
#
#
#  11%|█         | 55/500 [01:17<09:47,  1.32s/it]
#
#
#  11%|█         | 56/500 [01:18<09:44,  1.32s/it]
#
#
#  11%|█▏        | 57/500 [01:20<09:42,  1.32s/it]
#
#
#  12%|█▏        | 58/500 [01:21<09:38,  1.31s/it]
#
#
#  12%|█▏        | 59/500 [01:22<09:35,  1.30s/it]
#
#
#  12%|█▏        | 60/500 [01:23<09:31,  1.30s/it]
#
#
#  12%|█▏        | 61/500 [01:25<09:30,  1.30s/it]
#
#
#  12%|█▏        | 62/500 [01:26<09:39,  1.32s/it]
#
#
#  13%|█▎        | 63/500 [01:28<09:53,  1.36s/it]
#
#
#  13%|█▎        | 64/500 [01:29<09:40,  1.33s/it]
#
#
#  13%|█▎        | 65/500 [01:30<09:34,  1.32s/it]
#
#
#  13%|█▎        | 66/500 [01:31<09:42,  1.34s/it]
#
#
#  13%|█▎        | 67/500 [01:33<10:44,  1.49s/it]
#
#
#  14%|█▎        | 68/500 [01:36<12:18,  1.71s/it]
#
#
#  14%|█▍        | 69/500 [01:38<13:44,  1.91s/it]
#
#
#  14%|█▍        | 70/500 [01:40<13:36,  1.90s/it]
#
#
#  14%|█▍        | 71/500 [01:41<12:46,  1.79s/it]
#
#
#  14%|█▍        | 72/500 [01:43<12:00,  1.68s/it]
#
#
#  15%|█▍        | 73/500 [01:45<12:07,  1.70s/it]
#
#
#  15%|█▍        | 74/500 [01:46<12:30,  1.76s/it]
#
#
#  15%|█▌        | 75/500 [01:48<11:49,  1.67s/it]
#
#
#  15%|█▌        | 76/500 [01:49<11:04,  1.57s/it]
#
#
#  15%|█▌        | 77/500 [01:51<10:56,  1.55s/it]
#
#
#  16%|█▌        | 78/500 [01:52<10:41,  1.52s/it]
#
#
#
#
#  49%|████▉     | 245/500 [06:07<06:37,  1.56s/it]
#
#
#  49%|████▉     | 246/500 [06:09<06:35,  1.56s/it]
#
#
#  49%|████▉     | 247/500 [06:10<06:46,  1.61s/it]
#
#
#  50%|████▉     | 248/500 [06:12<06:55,  1.65s/it]
#
#
#  50%|████▉     | 249/500 [06:13<06:36,  1.58s/it]
#
#
#  50%|█████     | 250/500 [06:15<06:18,  1.51s/it]
#
#
#  50%|█████     | 251/500 [06:16<06:02,  1.46s/it]
#
#
#  50%|█████     | 252/500 [06:18<05:56,  1.44s/it]
#
#
#  51%|█████     | 253/500 [06:19<05:46,  1.40s/it]
#
#
#  51%|█████     | 254/500 [06:20<05:44,  1.40s/it]
#
#
#  51%|█████     | 255/500 [06:22<05:45,  1.41s/it]
#
#
#  51%|█████     | 256/500 [06:23<05:35,  1.38s/it]
#
#
#  51%|█████▏    | 257/500 [06:24<05:30,  1.36s/it]
#
#
#  52%|█████▏    | 258/500 [06:26<05:24,  1.34s/it]
#
#
#  52%|█████▏    | 259/500 [06:27<05:20,  1.33s/it]
#
#
#  52%|█████▏    | 260/500 [06:29<05:51,  1.46s/it]
#
#
#  52%|█████▏    | 261/500 [06:31<06:20,  1.59s/it]
#
#
#  52%|█████▏    | 262/500 [06:33<06:57,  1.75s/it]
#
#
#  53%|█████▎    | 263/500 [06:35<07:19,  1.86s/it]
#
#
#  53%|█████▎    | 264/500 [06:37<07:51,  2.00s/it]
#
#
#  53%|█████▎    | 265/500 [06:39<07:20,  1.87s/it]
#
#
#  53%|█████▎    | 266/500 [06:40<06:39,  1.71s/it]
#
#
#  53%|█████▎    | 267/500 [06:41<06:16,  1.62s/it]
#
#
#  54%|█████▎    | 268/500 [06:43<05:52,  1.52s/it]
#
#
#  54%|█████▍    | 269/500 [06:44<05:34,  1.45s/it]
#
#
#  54%|█████▍    | 270/500 [06:45<05:28,  1.43s/it]
#
#
#  54%|█████▍    | 271/500 [06:47<05:17,  1.39s/it]
#
#
#  54%|█████▍    | 272/500 [06:48<05:09,  1.36s/it]
#
#
#  55%|█████▍    | 273/500 [06:49<05:08,  1.36s/it]
#
#
#  55%|█████▍    | 274/500 [06:51<05:07,  1.36s/it]
#
#
#  55%|█████▌    | 275/500 [06:52<05:04,  1.35s/it]
#
#
#  55%|█████▌    | 276/500 [06:53<04:59,  1.34s/it]
#
#
#  55%|█████▌    | 277/500 [06:55<04:55,  1.33s/it]
#
#
#  56%|█████▌    | 278/500 [06:56<04:51,  1.31s/it]
#
#
#  56%|█████▌    | 279/500 [06:57<04:48,  1.30s/it]
#
#
#  56%|█████▌    | 280/500 [06:58<04:46,  1.30s/it]
#
#
#  56%|█████▌    | 281/500 [07:00<04:43,  1.29s/it]
#
#
#  56%|█████▋    | 282/500 [07:01<04:47,  1.32s/it]
#
#
#  57%|█████▋    | 283/500 [07:03<04:58,  1.38s/it]
#
#
#  57%|█████▋    | 284/500 [07:04<05:21,  1.49s/it]
#
#
#  81%|████████  | 406/500 [10:00<02:02,  1.30s/it]
#
#
#  81%|████████▏ | 407/500 [10:02<02:01,  1.31s/it]
#
#
#  82%|████████▏ | 408/500 [10:03<01:59,  1.30s/it]
#
#
#  82%|████████▏ | 409/500 [10:06<02:34,  1.70s/it]
#
#
#  82%|████████▏ | 410/500 [10:07<02:21,  1.57s/it]
#
#
#  82%|████████▏ | 411/500 [10:08<02:11,  1.48s/it]
#
#
#  82%|████████▏ | 412/500 [10:09<02:06,  1.43s/it]
#
#
#  83%|████████▎ | 413/500 [10:11<02:00,  1.39s/it]
#
#
#  83%|████████▎ | 414/500 [10:12<01:56,  1.35s/it]
#
#
#  83%|████████▎ | 415/500 [10:13<01:53,  1.34s/it]
#
#
#  83%|████████▎ | 416/500 [10:15<01:53,  1.35s/it]
#
#
#  83%|████████▎ | 417/500 [10:16<01:50,  1.33s/it]
#
#
#  84%|████████▎ | 418/500 [10:17<01:48,  1.32s/it]
#
#
#  84%|████████▍ | 419/500 [10:19<01:45,  1.31s/it]
#
#
#  84%|████████▍ | 420/500 [10:20<01:44,  1.30s/it]
#
#
#  84%|████████▍ | 421/500 [10:21<01:42,  1.29s/it]
#
#
#  84%|████████▍ | 422/500 [10:22<01:40,  1.29s/it]
#
#
#  85%|████████▍ | 423/500 [10:24<01:39,  1.29s/it]
#
#
#  85%|████████▍ | 424/500 [10:25<01:40,  1.32s/it]
#
#
#  85%|████████▌ | 425/500 [10:26<01:37,  1.31s/it]
#
#
#  85%|████████▌ | 426/500 [10:28<01:36,  1.30s/it]
#
#
#  85%|████████▌ | 427/500 [10:29<01:34,  1.29s/it]
#
#
#  86%|████████▌ | 428/500 [10:30<01:33,  1.29s/it]
#
#
#  86%|████████▌ | 429/500 [10:32<01:33,  1.32s/it]
#
#
#  86%|████████▌ | 430/500 [10:33<01:31,  1.31s/it]
#
#
#  86%|████████▌ | 431/500 [10:34<01:31,  1.32s/it]
#
#
#  86%|████████▋ | 432/500 [10:36<01:32,  1.36s/it]
#
#
#  87%|████████▋ | 433/500 [10:37<01:29,  1.33s/it]
#
#
#  87%|████████▋ | 434/500 [10:38<01:26,  1.32s/it]
#
#
#  87%|████████▋ | 435/500 [10:39<01:25,  1.31s/it]
#
#
#  87%|████████▋ | 436/500 [10:41<01:23,  1.30s/it]
#
#
#  87%|████████▋ | 437/500 [10:42<01:21,  1.30s/it]
#
#
#  88%|████████▊ | 438/500 [10:43<01:19,  1.29s/it]
#
#
#  88%|████████▊ | 439/500 [10:45<01:19,  1.30s/it]
#
#
#  88%|████████▊ | 440/500 [10:46<01:19,  1.32s/it]
#
#
#  88%|████████▊ | 441/500 [10:47<01:17,  1.31s/it]
#
#
#  88%|████████▊ | 442/500 [10:49<01:17,  1.33s/it]
#
#
#  89%|████████▊ | 443/500 [10:52<01:47,  1.89s/it]
#
#
#  89%|████████▉ | 444/500 [10:53<01:38,  1.76s/it]
#
#
#  89%|████████▉ | 445/500 [10:55<01:29,  1.63s/it]
#
#
#  89%|████████▉ | 446/500 [10:56<01:23,  1.55s/it]
#
#
#  89%|████████▉ | 447/500 [10:57<01:19,  1.50s/it]
#
#
#  90%|████████▉ | 448/500 [10:59<01:14,  1.43s/it]
#
#
#  90%|████████▉ | 449/500 [11:00<01:10,  1.39s/it]
#
#
#  90%|█████████ | 450/500 [11:01<01:07,  1.35s/it]
#
#
#  90%|█████████ | 451/500 [11:03<01:05,  1.34s/it]
#
#
#  90%|█████████ | 452/500 [11:04<01:05,  1.36s/it]
#
#
#  91%|█████████ | 453/500 [11:05<01:03,  1.36s/it]
#
#
#  91%|█████████ | 454/500 [11:07<01:03,  1.38s/it]
#
#
#  91%|█████████ | 455/500 [11:08<01:01,  1.36s/it]
#
#
#  91%|█████████ | 456/500 [11:09<00:59,  1.34s/it]
#
#
#  91%|█████████▏| 457/500 [11:11<00:57,  1.34s/it]
#
#
#  92%|█████████▏| 458/500 [11:12<00:55,  1.32s/it]
#
#
#  92%|█████████▏| 459/500 [11:13<00:53,  1.31s/it]
#
#
#  92%|█████████▏| 460/500 [11:15<00:53,  1.33s/it]
#
#
#  92%|█████████▏| 461/500 [11:16<00:53,  1.37s/it]
#
#
#  92%|█████████▏| 462/500 [11:17<00:51,  1.36s/it]
#
#
#  93%|█████████▎| 463/500 [11:19<00:49,  1.33s/it]
#
#
#  93%|█████████▎| 464/500 [11:20<00:47,  1.32s/it]
#
#
#  93%|█████████▎| 465/500 [11:21<00:45,  1.31s/it]
#
#
#  93%|█████████▎| 466/500 [11:23<00:44,  1.30s/it]
#
#
#  93%|█████████▎| 467/500 [11:24<00:42,  1.29s/it]
#
#
#  94%|█████████▎| 468/500 [11:25<00:41,  1.29s/it]
#
#
#  94%|█████████▍| 469/500 [11:27<00:41,  1.33s/it]
#
#
#  94%|█████████▍| 470/500 [11:28<00:40,  1.35s/it]
#
#
#  94%|█████████▍| 471/500 [11:29<00:38,  1.33s/it]
#
#
#  94%|█████████▍| 472/500 [11:31<00:37,  1.32s/it]
#
#
#  95%|█████████▍| 473/500 [11:32<00:35,  1.30s/it]
#
#
#  95%|█████████▍| 474/500 [11:33<00:33,  1.29s/it]
#
#
#  95%|█████████▌| 475/500 [11:34<00:32,  1.29s/it]
#
#
#  95%|█████████▌| 476/500 [11:36<00:31,  1.29s/it]
#
#
#  95%|█████████▌| 477/500 [11:37<00:30,  1.31s/it]
#
#
#  96%|█████████▌| 478/500 [11:38<00:28,  1.30s/it]
#
#
#  96%|█████████▌| 479/500 [11:40<00:27,  1.31s/it]
#
#
#  96%|█████████▌| 480/500 [11:41<00:26,  1.30s/it]
#
#
#  96%|█████████▌| 481/500 [11:42<00:24,  1.29s/it]
#
#
#  96%|█████████▋| 482/500 [11:43<00:23,  1.31s/it]
#
#
#  97%|█████████▋| 483/500 [11:45<00:22,  1.29s/it]
#
#
#  97%|█████████▋| 484/500 [11:46<00:20,  1.30s/it]
#
#
#  97%|█████████▋| 485/500 [11:47<00:19,  1.33s/it]
#
#
#  97%|█████████▋| 486/500 [11:49<00:18,  1.31s/it]
#
#
#  97%|█████████▋| 487/500 [11:50<00:17,  1.31s/it]
#
#
#  98%|█████████▊| 488/500 [11:51<00:15,  1.32s/it]
#
#
#  98%|█████████▊| 489/500 [11:53<00:15,  1.44s/it]
#
#
#  98%|█████████▊| 490/500 [11:55<00:16,  1.65s/it]
#
#
#  98%|█████████▊| 491/500 [11:58<00:17,  1.94s/it]
#
#
#  98%|█████████▊| 492/500 [12:00<00:15,  1.88s/it]
#
#
#  99%|█████████▊| 493/500 [12:01<00:12,  1.73s/it]
#
#
#  99%|█████████▉| 494/500 [12:02<00:09,  1.60s/it]
#
#
#  99%|█████████▉| 495/500 [12:04<00:07,  1.52s/it]
#
#
#  99%|█████████▉| 496/500 [12:05<00:05,  1.46s/it]
#
#
#  99%|█████████▉| 497/500 [12:06<00:04,  1.43s/it]
#
#
# 100%|█████████▉| 498/500 [12:08<00:03,  1.58s/it]
#
#
# 100%|█████████▉| 499/500 [12:10<00:01,  1.59s/it]
#
#
# 100%|██████████| 500/500 [12:11<00:00,  1.46s/it]
# 0.838
# 0.838
# 0.046

# %%
rho = 0.5
tstats, het_tstats, clust_tstats = regression_fits(data, rho, 500)
print((np.abs(tstats)>1.96).mean())
print((np.abs(het_tstats)>1.96).mean())
print((np.abs(clust_tstats)>1.96).mean())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#
#
#   0%|          | 1/500 [00:01<10:58,  1.32s/it]
#
#
#   0%|          | 2/500 [00:02<10:54,  1.31s/it]
#
#
#   1%|          | 3/500 [00:03<10:57,  1.32s/it]
#
#
#   1%|          | 4/500 [00:05<10:57,  1.33s/it]
#
#
#   1%|          | 5/500 [00:06<11:19,  1.37s/it]
#
#
#   1%|          | 6/500 [00:08<11:18,  1.37s/it]
#
#
#   1%|▏         | 7/500 [00:09<11:08,  1.36s/it]
#
#
#   2%|▏         | 8/500 [00:10<10:58,  1.34s/it]
#
#
#   2%|▏         | 9/500 [00:12<10:58,  1.34s/it]
#
#
#   2%|▏         | 10/500 [00:13<10:48,  1.32s/it]
#
#
#   2%|▏         | 11/500 [00:14<10:45,  1.32s/it]
#
#
#   2%|▏         | 12/500 [00:16<11:01,  1.36s/it]
#
#
#   3%|▎         | 13/500 [00:17<11:02,  1.36s/it]
#
#
#   3%|▎         | 14/500 [00:19<11:46,  1.45s/it]
#
#
#   3%|▎         | 15/500 [00:20<12:28,  1.54s/it]
#
#
#   3%|▎         | 16/500 [00:23<13:45,  1.71s/it]
#
#
#   3%|▎         | 17/500 [00:26<18:15,  2.27s/it]
#
#
#   4%|▎         | 18/500 [00:29<19:38,  2.45s/it]
#
#
#   4%|▍         | 19/500 [00:30<16:55,  2.11s/it]
#
#
#   4%|▍         | 20/500 [00:32<15:21,  1.92s/it]
#
#
#   4%|▍         | 21/500 [00:34<14:54,  1.87s/it]
#
#
#   4%|▍         | 22/500 [00:35<14:12,  1.78s/it]
#
#
#   5%|▍         | 23/500 [00:37<13:46,  1.73s/it]
#
#
#   5%|▍         | 24/500 [00:38<12:46,  1.61s/it]
#
#
#   5%|▌         | 25/500 [00:39<12:08,  1.53s/it]
#
#
#   5%|▌         | 26/500 [00:41<11:48,  1.49s/it]
#
#
#   5%|▌         | 27/500 [00:42<11:25,  1.45s/it]
#
#
#   6%|▌         | 28/500 [00:44<11:13,  1.43s/it]
#
#
#   6%|▌         | 29/500 [00:45<11:00,  1.40s/it]
#
#
#   6%|▌         | 30/500 [00:46<11:03,  1.41s/it]
#
#
#   6%|▌         | 31/500 [00:48<10:55,  1.40s/it]
#
#
#   6%|▋         | 32/500 [00:49<10:44,  1.38s/it]
#
#
#   7%|▋         | 33/500 [00:50<10:36,  1.36s/it]
#
#
#   7%|▋         | 34/500 [00:52<10:37,  1.37s/it]
#
#
#   7%|▋         | 35/500 [00:53<10:32,  1.36s/it]
#
#
#   7%|▋         | 36/500 [00:54<10:25,  1.35s/it]
#
#
#   7%|▋         | 37/500 [00:56<10:22,  1.35s/it]
#
#
#   8%|▊         | 38/500 [00:57<10:43,  1.39s/it]
#
#
#   8%|▊         | 39/500 [00:59<10:35,  1.38s/it]
#
#
#   8%|▊         | 40/500 [01:00<10:18,  1.35s/it]
#
#
#   8%|▊         | 41/500 [01:01<10:09,  1.33s/it]
#
#
#   8%|▊         | 42/500 [01:02<10:10,  1.33s/it]
#
#
#   9%|▊         | 43/500 [01:04<10:01,  1.32s/it]
#
#
#   9%|▉         | 44/500 [01:05<10:18,  1.36s/it]
#
#
#   9%|▉         | 45/500 [01:07<10:43,  1.41s/it]
#
#
#   9%|▉         | 46/500 [01:08<10:28,  1.38s/it]
#
#
#   9%|▉         | 47/500 [01:09<10:22,  1.37s/it]
#
#
#  10%|▉         | 48/500 [01:11<10:07,  1.34s/it]
#
#
#  10%|▉         | 49/500 [01:12<09:59,  1.33s/it]
#
#
#  10%|█         | 50/500 [01:13<09:58,  1.33s/it]
#
#
#  10%|█         | 51/500 [01:15<09:52,  1.32s/it]
#
#
#  10%|█         | 52/500 [01:16<09:46,  1.31s/it]
#
#
#  11%|█         | 53/500 [01:17<10:17,  1.38s/it]
#
#
#  11%|█         | 54/500 [01:19<10:10,  1.37s/it]
#
#
#  11%|█         | 55/500 [01:20<09:56,  1.34s/it]
#
#
#  11%|█         | 56/500 [01:21<09:48,  1.33s/it]
#
#
#  11%|█▏        | 57/500 [01:23<09:44,  1.32s/it]
#
#
#  12%|█▏        | 58/500 [01:24<09:41,  1.32s/it]
#
#
#  12%|█▏        | 59/500 [01:25<09:37,  1.31s/it]
#
#
#  12%|█▏        | 60/500 [01:27<09:41,  1.32s/it]
#
#
#  12%|█▏        | 61/500 [01:28<09:44,  1.33s/it]
#
#
#  12%|█▏        | 62/500 [01:29<09:47,  1.34s/it]
#
#
#  13%|█▎        | 63/500 [01:31<09:41,  1.33s/it]
#
#
#  13%|█▎        | 64/500 [01:32<09:35,  1.32s/it]
#
#
#  13%|█▎        | 65/500 [01:33<09:27,  1.30s/it]
#
#
#  13%|█▎        | 66/500 [01:34<09:26,  1.31s/it]
#
#
#  13%|█▎        | 67/500 [01:36<09:20,  1.29s/it]
#
#
#  14%|█▎        | 68/500 [01:37<09:27,  1.31s/it]
#
#
#  14%|█▍        | 69/500 [01:39<09:40,  1.35s/it]
#
#
#  14%|█▍        | 70/500 [01:40<09:33,  1.33s/it]
#
#
#  14%|█▍        | 71/500 [01:41<09:32,  1.33s/it]
#
#
#  14%|█▍        | 72/500 [01:42<09:28,  1.33s/it]
#
#
#  15%|█▍        | 73/500 [01:44<09:20,  1.31s/it]
#
#
#  15%|█▍        | 74/500 [01:45<09:15,  1.30s/it]
#
#
#  15%|█▌        | 75/500 [01:46<09:15,  1.31s/it]
#
#
#  15%|█▌        | 76/500 [01:48<09:21,  1.33s/it]
#
#
#  15%|█▌        | 77/500 [01:49<09:18,  1.32s/it]
#
#
#  16%|█▌        | 78/500 [01:50<09:14,  1.32s/it]
#
#
#  16%|█▌        | 79/500 [01:52<09:15,  1.32s/it]
#
#
#  16%|█▌        | 80/500 [01:53<09:10,  1.31s/it]
#
#
#  16%|█▌        | 81/500 [01:54<09:07,  1.31s/it]
#
#
#  16%|█▋        | 82/500 [01:56<09:08,  1.31s/it]
#
#
#  17%|█▋        | 83/500 [01:57<09:07,  1.31s/it]
#
#
#  17%|█▋        | 84/500 [01:59<09:47,  1.41s/it]
#
#
#  17%|█▋        | 85/500 [02:00<09:32,  1.38s/it]
#
#
#  17%|█▋        | 86/500 [02:01<09:51,  1.43s/it]
#
#
#  17%|█▋        | 87/500 [02:03<09:54,  1.44s/it]
#
#
#  18%|█▊        | 88/500 [02:04<10:08,  1.48s/it]
#
#
#  18%|█▊        | 89/500 [02:06<09:57,  1.45s/it]
#
#
#  18%|█▊        | 90/500 [02:07<09:50,  1.44s/it]
#
#
#  18%|█▊        | 91/500 [02:09<10:00,  1.47s/it]
#
#
#  18%|█▊        | 92/500 [02:10<09:38,  1.42s/it]
#
#
#  19%|█▊        | 93/500 [02:11<09:34,  1.41s/it]
#
#
#  19%|█▉        | 94/500 [02:13<09:18,  1.38s/it]
#
#
#  19%|█▉        | 95/500 [02:14<09:10,  1.36s/it]
#
#
#  19%|█▉        | 96/500 [02:15<09:04,  1.35s/it]
#
#
#  19%|█▉        | 97/500 [02:17<08:58,  1.34s/it]
#
#
#  20%|█▉        | 98/500 [02:18<08:56,  1.34s/it]
#
#
#  20%|█▉        | 99/500 [02:19<09:03,  1.35s/it]
#
#
#  20%|██        | 100/500 [02:21<08:56,  1.34s/it]
#
#
#  20%|██        | 101/500 [02:22<08:56,  1.34s/it]
#
#
#  20%|██        | 102/500 [02:23<08:57,  1.35s/it]
#
#
#  21%|██        | 103/500 [02:25<08:48,  1.33s/it]
#
#
#  21%|██        | 104/500 [02:26<08:44,  1.32s/it]
#
#
#  21%|██        | 105/500 [02:27<08:47,  1.34s/it]
#
#
#  21%|██        | 106/500 [02:29<08:52,  1.35s/it]
#
#
#  21%|██▏       | 107/500 [02:30<08:50,  1.35s/it]
#
#
#
#
#  55%|█████▍    | 273/500 [06:26<05:02,  1.33s/it]
#
#
#  55%|█████▍    | 274/500 [06:27<04:57,  1.32s/it]
#
#
#  55%|█████▌    | 275/500 [06:28<04:58,  1.33s/it]
#
#
#  55%|█████▌    | 276/500 [06:30<04:56,  1.33s/it]
#
#
#  55%|█████▌    | 277/500 [06:31<04:52,  1.31s/it]
#
#
#  56%|█████▌    | 278/500 [06:32<04:53,  1.32s/it]
#
#
#  56%|█████▌    | 279/500 [06:34<05:02,  1.37s/it]
#
#
#  56%|█████▌    | 280/500 [06:35<04:55,  1.34s/it]
#
#
#  56%|█████▌    | 281/500 [06:36<04:50,  1.33s/it]
#
#
#  56%|█████▋    | 282/500 [06:38<04:47,  1.32s/it]
#
#
#  57%|█████▋    | 283/500 [06:39<04:53,  1.35s/it]
#
#
#  57%|█████▋    | 284/500 [06:41<04:55,  1.37s/it]
#
#
#  57%|█████▋    | 285/500 [06:42<04:51,  1.35s/it]
#
#
#  57%|█████▋    | 286/500 [06:43<04:44,  1.33s/it]
#
#
#  57%|█████▋    | 287/500 [06:44<04:41,  1.32s/it]
#
#
#  58%|█████▊    | 288/500 [06:46<04:39,  1.32s/it]
#
#
#  58%|█████▊    | 289/500 [06:47<04:37,  1.31s/it]
#
#
#  58%|█████▊    | 290/500 [06:48<04:34,  1.31s/it]
#
#
#  58%|█████▊    | 291/500 [06:50<04:33,  1.31s/it]
#
#
#  58%|█████▊    | 292/500 [06:51<04:30,  1.30s/it]
#
#
#  59%|█████▊    | 293/500 [06:52<04:36,  1.34s/it]
#
#
#  59%|█████▉    | 294/500 [06:54<04:34,  1.33s/it]
#
#
#  59%|█████▉    | 295/500 [06:55<04:29,  1.32s/it]
#
#
#  59%|█████▉    | 296/500 [06:56<04:42,  1.38s/it]
#
#
#  59%|█████▉    | 297/500 [06:58<04:34,  1.35s/it]
#
#
#  60%|█████▉    | 298/500 [06:59<04:30,  1.34s/it]
#
#
#  60%|█████▉    | 299/500 [07:00<04:26,  1.33s/it]
#
#
#  60%|██████    | 300/500 [07:02<04:44,  1.42s/it]
#
#
#  60%|██████    | 301/500 [07:03<04:45,  1.43s/it]
#
#
#  60%|██████    | 302/500 [07:05<04:40,  1.41s/it]
#
#
#  61%|██████    | 303/500 [07:06<04:37,  1.41s/it]
#
#
#  61%|██████    | 304/500 [07:08<04:32,  1.39s/it]
#
#
#  61%|██████    | 305/500 [07:09<04:24,  1.36s/it]
#
#
#  61%|██████    | 306/500 [07:10<04:19,  1.34s/it]
#
#
#  61%|██████▏   | 307/500 [07:12<04:21,  1.35s/it]
#
#
#  62%|██████▏   | 308/500 [07:13<04:21,  1.36s/it]
#
#
#  62%|██████▏   | 309/500 [07:14<04:18,  1.35s/it]
#
#
#  62%|██████▏   | 310/500 [07:16<04:16,  1.35s/it]
#
#
#  62%|██████▏   | 311/500 [07:17<04:12,  1.34s/it]
#
#
#  62%|██████▏   | 312/500 [07:18<04:08,  1.32s/it]
#
#
#  79%|███████▊  | 393/500 [09:14<02:27,  1.38s/it]
#
#
#  79%|███████▉  | 394/500 [09:16<02:36,  1.48s/it]
#
#
#  79%|███████▉  | 395/500 [09:18<02:59,  1.71s/it]
#
#
#  79%|███████▉  | 396/500 [09:19<02:48,  1.62s/it]
#
#
#  79%|███████▉  | 397/500 [09:21<02:37,  1.53s/it]
#
#
#  80%|███████▉  | 398/500 [09:22<02:28,  1.46s/it]
#
#
#  80%|███████▉  | 399/500 [09:23<02:24,  1.43s/it]
#
#
#  80%|████████  | 400/500 [09:25<02:26,  1.46s/it]
#
#
#  80%|████████  | 401/500 [09:27<02:28,  1.50s/it]
#
#
#  80%|████████  | 402/500 [09:28<02:27,  1.50s/it]
#
#
#  81%|████████  | 403/500 [09:30<02:25,  1.50s/it]
#
#
#  81%|████████  | 404/500 [09:31<02:22,  1.49s/it]
#
#
#  81%|████████  | 405/500 [09:32<02:18,  1.46s/it]
#
#
#  81%|████████  | 406/500 [09:34<02:11,  1.40s/it]
#
#
#  81%|████████▏ | 407/500 [09:36<02:32,  1.64s/it]
#
#
#  82%|████████▏ | 408/500 [09:37<02:30,  1.64s/it]
#
#
#  82%|████████▏ | 409/500 [09:40<02:45,  1.82s/it]
#
#
#  82%|████████▏ | 410/500 [09:41<02:41,  1.79s/it]
#
#
#  82%|████████▏ | 411/500 [09:43<02:29,  1.68s/it]
#
#
#  82%|████████▏ | 412/500 [09:45<02:31,  1.72s/it]
#
#
#  83%|████████▎ | 413/500 [09:47<02:39,  1.84s/it]
#
#
#  83%|████████▎ | 414/500 [09:48<02:32,  1.77s/it]
#
#
#  83%|████████▎ | 415/500 [09:50<02:19,  1.65s/it]
#
#
#  83%|████████▎ | 416/500 [09:51<02:09,  1.54s/it]
#
#
#  83%|████████▎ | 417/500 [09:52<02:01,  1.46s/it]
#
#
#  84%|████████▎ | 418/500 [09:54<01:55,  1.41s/it]
#
#
#  84%|████████▍ | 419/500 [09:55<02:05,  1.55s/it]
#
#
#  84%|████████▍ | 420/500 [09:57<02:00,  1.51s/it]
#
#
#  84%|████████▍ | 421/500 [09:58<01:56,  1.48s/it]
#
#
#  84%|████████▍ | 422/500 [10:00<01:50,  1.42s/it]
#
#
#  85%|████████▍ | 423/500 [10:01<01:46,  1.38s/it]
#
#
#  85%|████████▍ | 424/500 [10:02<01:42,  1.35s/it]
#
#
#  85%|████████▌ | 425/500 [10:04<01:41,  1.35s/it]
#
#
#  85%|████████▌ | 426/500 [10:05<01:41,  1.37s/it]
#
#
#  85%|████████▌ | 427/500 [10:06<01:40,  1.38s/it]
#
#
#  86%|████████▌ | 428/500 [10:08<01:46,  1.48s/it]
#
#
#  86%|████████▌ | 429/500 [10:10<01:46,  1.49s/it]
#
#
#  86%|████████▌ | 430/500 [10:11<01:43,  1.48s/it]
#
#
#  86%|████████▌ | 431/500 [10:12<01:39,  1.45s/it]
#
#
#  86%|████████▋ | 432/500 [10:14<01:38,  1.45s/it]
#
#
#  87%|████████▋ | 433/500 [10:16<01:44,  1.55s/it]
#
#
#  87%|████████▋ | 434/500 [10:17<01:39,  1.50s/it]
#
#
#  87%|████████▋ | 435/500 [10:19<01:40,  1.54s/it]
#
#
#  87%|████████▋ | 436/500 [10:21<01:46,  1.67s/it]
#
#
#  87%|████████▋ | 437/500 [10:22<01:42,  1.63s/it]
#
#
#  88%|████████▊ | 438/500 [10:24<01:36,  1.56s/it]
#
#
#  88%|████████▊ | 439/500 [10:25<01:34,  1.55s/it]
#
#
#  88%|████████▊ | 440/500 [10:27<01:30,  1.52s/it]
#
#
#  88%|████████▊ | 441/500 [10:28<01:25,  1.46s/it]
#
#
#  88%|████████▊ | 442/500 [10:29<01:22,  1.41s/it]
#
#
#  89%|████████▊ | 443/500 [10:31<01:23,  1.46s/it]
#
#
#  89%|████████▉ | 444/500 [10:32<01:21,  1.45s/it]
#
#
#  89%|████████▉ | 445/500 [10:33<01:17,  1.42s/it]
#
#
#  89%|████████▉ | 446/500 [10:35<01:14,  1.39s/it]
#
#
#  89%|████████▉ | 447/500 [10:37<01:20,  1.52s/it]
#
#
#  90%|████████▉ | 448/500 [10:38<01:16,  1.46s/it]
#
#
#  90%|████████▉ | 449/500 [10:39<01:12,  1.42s/it]
#
#
#  90%|█████████ | 450/500 [10:41<01:09,  1.40s/it]
#
#
#  90%|█████████ | 451/500 [10:42<01:07,  1.38s/it]
#
#
#  90%|█████████ | 452/500 [10:43<01:05,  1.36s/it]
#
#
#  91%|█████████ | 453/500 [10:45<01:03,  1.36s/it]
#
#
#  91%|█████████ | 454/500 [10:46<01:06,  1.44s/it]
#
#
#  91%|█████████ | 455/500 [10:48<01:03,  1.41s/it]
#
#
#  91%|█████████ | 456/500 [10:49<01:00,  1.38s/it]
#
#
#  91%|█████████▏| 457/500 [10:50<00:58,  1.35s/it]
#
#
#  92%|█████████▏| 458/500 [10:52<00:56,  1.35s/it]
#
#
#  92%|█████████▏| 459/500 [10:53<00:54,  1.33s/it]
#
#
#  92%|█████████▏| 460/500 [10:54<00:53,  1.33s/it]
#
#
#  92%|█████████▏| 461/500 [10:56<00:56,  1.44s/it]
#
#
#  92%|█████████▏| 462/500 [10:57<00:55,  1.45s/it]
#
#
#  93%|█████████▎| 463/500 [10:59<00:52,  1.43s/it]
#
#
#  93%|█████████▎| 464/500 [11:00<00:49,  1.39s/it]
#
#
#  93%|█████████▎| 465/500 [11:01<00:47,  1.36s/it]
#
#
#  93%|█████████▎| 466/500 [11:03<00:45,  1.35s/it]
#
#
#  93%|█████████▎| 467/500 [11:04<00:43,  1.33s/it]
#
#
#  94%|█████████▎| 468/500 [11:05<00:42,  1.34s/it]
#
#
#  94%|█████████▍| 469/500 [11:07<00:45,  1.46s/it]
#
#
#  94%|█████████▍| 470/500 [11:08<00:42,  1.42s/it]
#
#
#  94%|█████████▍| 471/500 [11:10<00:40,  1.39s/it]
#
#
#  94%|█████████▍| 472/500 [11:11<00:38,  1.36s/it]
#
#
#  95%|█████████▍| 473/500 [11:12<00:36,  1.33s/it]
#
#
#  95%|█████████▍| 474/500 [11:14<00:34,  1.33s/it]
#
#
#  95%|█████████▌| 475/500 [11:15<00:33,  1.32s/it]
#
#
#  95%|█████████▌| 476/500 [11:16<00:32,  1.36s/it]
#
#
#  95%|█████████▌| 477/500 [11:18<00:31,  1.35s/it]
#
#
#  96%|█████████▌| 478/500 [11:19<00:29,  1.34s/it]
#
#
#  96%|█████████▌| 479/500 [11:20<00:27,  1.33s/it]
#
#
#  96%|█████████▌| 480/500 [11:22<00:26,  1.34s/it]
#
#
#  96%|█████████▌| 481/500 [11:23<00:27,  1.43s/it]
#
#
#  96%|█████████▋| 482/500 [11:25<00:25,  1.40s/it]
#
#
#  97%|█████████▋| 483/500 [11:26<00:25,  1.51s/it]
#
#
#  97%|█████████▋| 484/500 [11:28<00:23,  1.49s/it]
#
#
#  97%|█████████▋| 485/500 [11:29<00:22,  1.51s/it]
#
#
#  97%|█████████▋| 486/500 [11:31<00:20,  1.47s/it]
#
#
#  97%|█████████▋| 487/500 [11:32<00:18,  1.43s/it]
#
#
#  98%|█████████▊| 488/500 [11:33<00:16,  1.41s/it]
#
#
#  98%|█████████▊| 489/500 [11:35<00:15,  1.38s/it]
#
#
#  98%|█████████▊| 490/500 [11:36<00:14,  1.45s/it]
#
#
#  98%|█████████▊| 491/500 [11:38<00:13,  1.50s/it]
#
#
#  98%|█████████▊| 492/500 [11:39<00:11,  1.47s/it]
#
#
#  99%|█████████▊| 493/500 [11:41<00:10,  1.43s/it]
#
#
#  99%|█████████▉| 494/500 [11:42<00:08,  1.43s/it]
#
#
#  99%|█████████▉| 495/500 [11:44<00:07,  1.46s/it]
#
#
#  99%|█████████▉| 496/500 [11:45<00:05,  1.47s/it]
#
#
#  99%|█████████▉| 497/500 [11:47<00:05,  1.73s/it]
#
#
# 100%|█████████▉| 498/500 [11:49<00:03,  1.65s/it]
#
#
# 100%|█████████▉| 499/500 [11:50<00:01,  1.56s/it]
#
#
# 100%|██████████| 500/500 [11:52<00:00,  1.42s/it]
# 0.952
# 0.95
# 0.072

# %%
rho = 0.8
tstats, het_tstats, clust_tstats = regression_fits(data, rho, 500)
print((np.abs(tstats)>1.96).mean())
print((np.abs(het_tstats)>1.96).mean())
print((np.abs(clust_tstats)>1.96).mean())
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#
#
#   0%|          | 1/500 [00:01<12:35,  1.51s/it]
#
#
#   0%|          | 2/500 [00:02<11:59,  1.44s/it]
#
#
#   1%|          | 3/500 [00:04<11:55,  1.44s/it]
#
#
#   1%|          | 4/500 [00:05<12:01,  1.45s/it]
#
#
#   1%|          | 5/500 [00:07<11:37,  1.41s/it]
#
#
#   1%|          | 6/500 [00:08<11:15,  1.37s/it]
#
#
#   1%|▏         | 7/500 [00:09<11:20,  1.38s/it]
#
#
#   2%|▏         | 8/500 [00:11<11:11,  1.36s/it]
#
#
#   2%|▏         | 9/500 [00:12<11:11,  1.37s/it]
#
#
#   2%|▏         | 10/500 [00:13<11:06,  1.36s/it]
#
#
#   2%|▏         | 11/500 [00:15<11:45,  1.44s/it]
#
#
#   2%|▏         | 12/500 [00:16<11:38,  1.43s/it]
#
#
#   3%|▎         | 13/500 [00:18<11:24,  1.41s/it]
#
#
#   3%|▎         | 14/500 [00:19<11:28,  1.42s/it]
#
#
#   3%|▎         | 15/500 [00:20<11:12,  1.39s/it]
#
#
#   3%|▎         | 16/500 [00:22<11:18,  1.40s/it]
#
#
#   3%|▎         | 17/500 [00:23<11:53,  1.48s/it]
#
#
#   4%|▎         | 18/500 [00:25<12:59,  1.62s/it]
#
#
#   4%|▍         | 19/500 [00:27<12:41,  1.58s/it]
#
#
#   4%|▍         | 20/500 [00:29<12:53,  1.61s/it]
#
#
#   4%|▍         | 21/500 [00:31<13:54,  1.74s/it]
#
#
#   4%|▍         | 22/500 [00:32<13:35,  1.71s/it]
#
#
#   5%|▍         | 23/500 [00:34<14:12,  1.79s/it]
#
#
#   5%|▍         | 24/500 [00:36<14:04,  1.77s/it]
#
#
#   5%|▌         | 25/500 [00:37<13:12,  1.67s/it]
#
#
#   5%|▌         | 26/500 [00:39<12:26,  1.57s/it]
#
#
#   5%|▌         | 27/500 [00:40<11:49,  1.50s/it]
#
#
#   6%|▌         | 28/500 [00:41<11:33,  1.47s/it]
#
#
#   6%|▌         | 29/500 [00:43<11:12,  1.43s/it]
#
#
#   6%|▌         | 30/500 [00:44<11:09,  1.43s/it]
#
#
#   6%|▌         | 31/500 [00:46<12:20,  1.58s/it]
#
#
#   6%|▋         | 32/500 [00:48<12:32,  1.61s/it]
#
#
#   7%|▋         | 33/500 [00:49<12:22,  1.59s/it]
#
#
#   7%|▋         | 34/500 [00:51<12:15,  1.58s/it]
#
#
#   7%|▋         | 35/500 [00:53<13:17,  1.71s/it]
#
#
#   7%|▋         | 36/500 [00:56<16:57,  2.19s/it]
#
#
#   7%|▋         | 37/500 [00:59<19:14,  2.49s/it]
#
#
#   8%|▊         | 38/500 [01:01<17:38,  2.29s/it]
#
#
#   8%|▊         | 39/500 [01:03<15:25,  2.01s/it]
#
#
#   8%|▊         | 40/500 [01:04<14:10,  1.85s/it]
#
#
#   8%|▊         | 41/500 [01:06<13:39,  1.79s/it]
#
#
#   8%|▊         | 42/500 [01:07<12:54,  1.69s/it]
#
#
#   9%|▊         | 43/500 [01:09<12:27,  1.64s/it]
#
#
#   9%|▉         | 44/500 [01:10<12:13,  1.61s/it]
#
#
#   9%|▉         | 45/500 [01:12<12:06,  1.60s/it]
#
#
#   9%|▉         | 46/500 [01:13<11:35,  1.53s/it]
#
#
#   9%|▉         | 47/500 [01:15<11:39,  1.54s/it]
#
#
#  10%|▉         | 48/500 [01:17<13:13,  1.76s/it]
#
#
#  10%|▉         | 49/500 [01:19<12:35,  1.67s/it]
#
#
#  10%|█         | 50/500 [01:20<12:11,  1.63s/it]
#
#
#  10%|█         | 51/500 [01:21<11:42,  1.56s/it]
#
#
#  10%|█         | 52/500 [01:23<11:43,  1.57s/it]
#
#
#  11%|█         | 53/500 [01:24<11:15,  1.51s/it]
#
#
#  11%|█         | 54/500 [01:26<12:11,  1.64s/it]
#
#
#  11%|█         | 55/500 [01:28<11:30,  1.55s/it]
#
#
#  11%|█         | 56/500 [01:29<11:05,  1.50s/it]
#
#
#  11%|█▏        | 57/500 [01:30<10:38,  1.44s/it]
#
#
#  12%|█▏        | 58/500 [01:32<10:28,  1.42s/it]
#
#
#  12%|█▏        | 59/500 [01:33<10:28,  1.42s/it]
#
#
#  12%|█▏        | 60/500 [01:35<10:14,  1.40s/it]
#
#
#  12%|█▏        | 61/500 [01:36<10:57,  1.50s/it]
#
#
#  12%|█▏        | 62/500 [01:38<11:14,  1.54s/it]
#
#
#  13%|█▎        | 63/500 [01:39<10:50,  1.49s/it]
#
#
#  13%|█▎        | 64/500 [01:41<10:25,  1.43s/it]
#
#
#  13%|█▎        | 65/500 [01:42<10:28,  1.44s/it]
#
#
#  13%|█▎        | 66/500 [01:43<10:16,  1.42s/it]
#
#
#  13%|█▎        | 67/500 [01:45<10:04,  1.40s/it]
#
#
#  14%|█▎        | 68/500 [01:47<10:49,  1.50s/it]
#
#
#  14%|█▍        | 69/500 [01:48<10:32,  1.47s/it]
#
#
#  14%|█▍        | 70/500 [01:49<10:21,  1.44s/it]
#
#
#  14%|█▍        | 71/500 [01:51<11:17,  1.58s/it]
#
#
#  14%|█▍        | 72/500 [01:53<11:09,  1.56s/it]
#
#
#  15%|█▍        | 73/500 [01:54<10:47,  1.52s/it]
#
#
#  15%|█▍        | 74/500 [01:55<10:24,  1.47s/it]
#
#
#  15%|█▌        | 75/500 [01:57<10:16,  1.45s/it]
#
#
#  15%|█▌        | 76/500 [01:58<10:01,  1.42s/it]
#
#
#  15%|█▌        | 77/500 [02:00<10:15,  1.45s/it]
#
#
#  16%|█▌        | 78/500 [02:01<10:32,  1.50s/it]
#
#
#  16%|█▌        | 79/500 [02:03<10:15,  1.46s/it]
#
#
#  16%|█▌        | 80/500 [02:04<09:58,  1.43s/it]
#
#
#  16%|█▌        | 81/500 [02:05<09:47,  1.40s/it]
#
#
#  16%|█▋        | 82/500 [02:07<09:47,  1.41s/it]
#
#
#  17%|█▋        | 83/500 [02:08<09:43,  1.40s/it]
#
#
#  17%|█▋        | 84/500 [02:10<09:33,  1.38s/it]
#
#
#  17%|█▋        | 85/500 [02:11<09:32,  1.38s/it]
#
#
#  17%|█▋        | 86/500 [02:12<09:37,  1.40s/it]
#
#
#  17%|█▋        | 87/500 [02:14<09:33,  1.39s/it]
#
#
#  18%|█▊        | 88/500 [02:15<09:28,  1.38s/it]
#
#
#  18%|█▊        | 89/500 [02:17<09:33,  1.40s/it]
#
#
#  18%|█▊        | 90/500 [02:18<09:32,  1.40s/it]
#
#
#  18%|█▊        | 91/500 [02:19<09:19,  1.37s/it]
#
#
#  18%|█▊        | 92/500 [02:21<09:15,  1.36s/it]
#
#
#  19%|█▊        | 93/500 [02:22<09:12,  1.36s/it]
#
#
#  19%|█▉        | 94/500 [02:24<09:40,  1.43s/it]
#  52%|█████▏    | 260/500 [06:52<06:46,  1.69s/it]
#
#
#  52%|█████▏    | 261/500 [06:53<06:31,  1.64s/it]
#
#
#  52%|█████▏    | 262/500 [06:55<06:26,  1.63s/it]
#
#
#  53%|█████▎    | 263/500 [06:57<06:46,  1.72s/it]
#
#
#  53%|█████▎    | 264/500 [06:58<06:37,  1.69s/it]
#
#
#  53%|█████▎    | 265/500 [07:00<06:30,  1.66s/it]
#
#
#  53%|█████▎    | 266/500 [07:01<06:14,  1.60s/it]
#
#
#  53%|█████▎    | 267/500 [07:04<07:50,  2.02s/it]
#
#
#  54%|█████▎    | 268/500 [07:07<08:45,  2.26s/it]
#
#
#  54%|█████▍    | 269/500 [07:09<08:42,  2.26s/it]
#
#
#  54%|█████▍    | 270/500 [07:11<07:43,  2.01s/it]
#
#
#  54%|█████▍    | 271/500 [07:13<07:56,  2.08s/it]
#
#
#  54%|█████▍    | 272/500 [07:14<07:04,  1.86s/it]
#
#
#  55%|█████▍    | 273/500 [07:16<06:40,  1.76s/it]
#
#
#  55%|█████▍    | 274/500 [07:17<06:12,  1.65s/it]
#
#
#  55%|█████▌    | 275/500 [07:19<05:55,  1.58s/it]
#
#
#  55%|█████▌    | 276/500 [07:20<05:47,  1.55s/it]
#
#
#  55%|█████▌    | 277/500 [07:22<05:35,  1.50s/it]
#
#
#  56%|█████▌    | 278/500 [07:23<05:35,  1.51s/it]
#
#
#  56%|█████▌    | 279/500 [07:25<05:25,  1.47s/it]
#
#
#  56%|█████▌    | 280/500 [07:26<05:16,  1.44s/it]
#
#
#  56%|█████▌    | 281/500 [07:27<05:10,  1.42s/it]
#
#
#  56%|█████▋    | 282/500 [07:29<05:04,  1.40s/it]
#
#
#  57%|█████▋    | 283/500 [07:30<05:09,  1.43s/it]
#
#
#  57%|█████▋    | 284/500 [07:32<05:05,  1.41s/it]
#
#
#  57%|█████▋    | 285/500 [07:33<05:04,  1.42s/it]
#
#
#  57%|█████▋    | 286/500 [07:34<04:57,  1.39s/it]
#
#
#  57%|█████▋    | 287/500 [07:36<04:52,  1.37s/it]
#
#
#  58%|█████▊    | 288/500 [07:37<04:47,  1.35s/it]
#
#
#  58%|█████▊    | 289/500 [07:38<04:54,  1.39s/it]
#
#
#  58%|█████▊    | 290/500 [07:40<04:50,  1.38s/it]
#
#
#  58%|█████▊    | 291/500 [07:41<04:48,  1.38s/it]
#
#
#  58%|█████▊    | 292/500 [07:43<04:47,  1.38s/it]
#
#
#  59%|█████▊    | 293/500 [07:44<04:43,  1.37s/it]
#
#
#  59%|█████▉    | 294/500 [07:45<04:55,  1.44s/it]
#
#
#  59%|█████▉    | 295/500 [07:47<04:53,  1.43s/it]
#
#
#  59%|█████▉    | 296/500 [07:48<04:52,  1.44s/it]
#
#
#  59%|█████▉    | 297/500 [07:50<04:44,  1.40s/it]
#
#
#  60%|█████▉    | 298/500 [07:51<04:37,  1.37s/it]
#
#
#  60%|█████▉    | 299/500 [07:52<04:34,  1.37s/it]
#
#
#
#
#  76%|███████▌  | 381/500 [09:43<02:38,  1.33s/it]
#
#
#  76%|███████▋  | 382/500 [09:45<02:45,  1.40s/it]
#
#
#  77%|███████▋  | 383/500 [09:46<02:40,  1.37s/it]
#
#
#  77%|███████▋  | 384/500 [09:48<02:38,  1.36s/it]
#
#
#  77%|███████▋  | 385/500 [09:49<02:35,  1.35s/it]
#
#
#  77%|███████▋  | 386/500 [09:50<02:35,  1.37s/it]
#
#
#  77%|███████▋  | 387/500 [09:52<02:32,  1.35s/it]
#
#
#  78%|███████▊  | 388/500 [09:53<02:29,  1.34s/it]
#
#
#  78%|███████▊  | 389/500 [09:54<02:28,  1.34s/it]
#
#
#  78%|███████▊  | 390/500 [09:56<02:34,  1.41s/it]
#
#
#  78%|███████▊  | 391/500 [09:57<02:32,  1.40s/it]
#
#
#  78%|███████▊  | 392/500 [09:59<02:28,  1.38s/it]
#
#
#  79%|███████▊  | 393/500 [10:00<02:25,  1.36s/it]
#
#
#  79%|███████▉  | 394/500 [10:01<02:22,  1.34s/it]
#
#
#  79%|███████▉  | 395/500 [10:02<02:19,  1.33s/it]
#
#
#  79%|███████▉  | 396/500 [10:04<02:19,  1.34s/it]
#
#
#  79%|███████▉  | 397/500 [10:05<02:22,  1.38s/it]
#
#
#  80%|███████▉  | 398/500 [10:07<02:19,  1.37s/it]
#
#
#  80%|███████▉  | 399/500 [10:08<02:19,  1.38s/it]
#
#
#  80%|████████  | 400/500 [10:09<02:16,  1.37s/it]
#
#
#  80%|████████  | 401/500 [10:11<02:12,  1.34s/it]
#
#
#  80%|████████  | 402/500 [10:12<02:18,  1.41s/it]
#
#
#  81%|████████  | 403/500 [10:15<02:57,  1.83s/it]
#
#
#  81%|████████  | 404/500 [10:17<02:55,  1.83s/it]
#
#
#  81%|████████  | 405/500 [10:18<02:43,  1.72s/it]
#
#
#  81%|████████  | 406/500 [10:20<02:29,  1.59s/it]
#
#
#  81%|████████▏ | 407/500 [10:21<02:21,  1.52s/it]
#
#
#  82%|████████▏ | 408/500 [10:23<02:31,  1.64s/it]
#
#
#  82%|████████▏ | 409/500 [10:25<02:29,  1.65s/it]
#
#
#  82%|████████▏ | 410/500 [10:26<02:25,  1.62s/it]
#
#
#  82%|████████▏ | 411/500 [10:28<02:19,  1.57s/it]
#
#
#  82%|████████▏ | 412/500 [10:30<02:40,  1.82s/it]
#
#
#  83%|████████▎ | 413/500 [10:33<03:00,  2.08s/it]
#
#
#  83%|████████▎ | 414/500 [10:34<02:47,  1.94s/it]
#
#
#  83%|████████▎ | 415/500 [10:36<02:29,  1.76s/it]
#
#
#  83%|████████▎ | 416/500 [10:37<02:17,  1.64s/it]
#
#
#  83%|████████▎ | 417/500 [10:38<02:06,  1.53s/it]
#
#
#  84%|████████▎ | 418/500 [10:40<01:59,  1.45s/it]
#
#
#  84%|████████▍ | 419/500 [10:41<01:53,  1.40s/it]
#
#
#  84%|████████▍ | 420/500 [10:42<01:49,  1.37s/it]
#
#
#  84%|████████▍ | 421/500 [10:43<01:46,  1.34s/it]
#
#
#  84%|████████▍ | 422/500 [10:45<01:44,  1.34s/it]
#
#
#  85%|████████▍ | 423/500 [10:46<01:45,  1.37s/it]
#
#
#  85%|████████▍ | 424/500 [10:47<01:42,  1.35s/it]
#
#
#  85%|████████▌ | 425/500 [10:49<01:39,  1.33s/it]
#
#
#  85%|████████▌ | 426/500 [10:50<01:37,  1.32s/it]
#
#
#  85%|████████▌ | 427/500 [10:51<01:37,  1.34s/it]
#
#
#  86%|████████▌ | 428/500 [10:53<01:43,  1.43s/it]
#
#
#  86%|████████▌ | 429/500 [10:55<02:00,  1.69s/it]
#
#
#  86%|████████▌ | 430/500 [11:01<03:17,  2.82s/it]
#
#
#  86%|████████▌ | 431/500 [11:04<03:11,  2.78s/it]
#
#
#  86%|████████▋ | 432/500 [11:05<02:48,  2.49s/it]
#
#
#  87%|████████▋ | 433/500 [11:07<02:32,  2.28s/it]
#
#
#  87%|████████▋ | 434/500 [11:09<02:16,  2.07s/it]
#
#
#  87%|████████▋ | 435/500 [11:10<02:02,  1.89s/it]
#
#
#  87%|████████▋ | 436/500 [11:11<01:49,  1.71s/it]
#
#
#  87%|████████▋ | 437/500 [11:13<01:41,  1.61s/it]
#
#
#  88%|████████▊ | 438/500 [11:15<01:49,  1.77s/it]
#
#
#  88%|████████▊ | 439/500 [11:21<03:04,  3.03s/it]
#
#
#  88%|████████▊ | 440/500 [11:24<02:53,  2.89s/it]
#
#
#  88%|████████▊ | 441/500 [11:25<02:26,  2.48s/it]
#
#
#  88%|████████▊ | 442/500 [11:27<02:10,  2.24s/it]
#
#
#  89%|████████▊ | 443/500 [11:28<01:57,  2.05s/it]
#
#
#  89%|████████▉ | 444/500 [11:30<01:45,  1.89s/it]
#
#
#  89%|████████▉ | 445/500 [11:35<02:42,  2.96s/it]
#
#
#  89%|████████▉ | 446/500 [11:40<03:02,  3.38s/it]
#
#
#  89%|████████▉ | 447/500 [11:41<02:28,  2.79s/it]
#
#
#  90%|████████▉ | 448/500 [11:43<02:11,  2.53s/it]
#
#
#  90%|████████▉ | 449/500 [11:47<02:36,  3.06s/it]
#
#
#  90%|█████████ | 450/500 [11:52<02:51,  3.42s/it]
#
#
#  90%|█████████ | 451/500 [11:54<02:34,  3.15s/it]
#
#
#  90%|█████████ | 452/500 [11:57<02:33,  3.21s/it]
#
#
#  91%|█████████ | 453/500 [12:02<02:45,  3.52s/it]
#
#
#  91%|█████████ | 454/500 [12:06<02:49,  3.68s/it]
#
#
#  91%|█████████ | 455/500 [12:08<02:21,  3.14s/it]
#
#
#  91%|█████████ | 456/500 [12:10<02:06,  2.86s/it]
#
#
#  91%|█████████▏| 457/500 [12:14<02:17,  3.19s/it]
#
#
#  92%|█████████▏| 458/500 [12:17<02:17,  3.27s/it]
#
#
#  92%|█████████▏| 459/500 [12:19<01:58,  2.89s/it]
#
#
#  92%|█████████▏| 460/500 [12:21<01:36,  2.42s/it]
#
#
#  92%|█████████▏| 461/500 [12:22<01:23,  2.15s/it]
#
#
#  92%|█████████▏| 462/500 [12:24<01:16,  2.01s/it]
#
#
#  93%|█████████▎| 463/500 [12:27<01:23,  2.25s/it]
#
#
#  93%|█████████▎| 464/500 [12:31<01:41,  2.81s/it]
#
#
#  93%|█████████▎| 465/500 [12:33<01:34,  2.71s/it]
#
#
#  93%|█████████▎| 466/500 [12:34<01:17,  2.28s/it]
#
#
#  93%|█████████▎| 467/500 [12:36<01:05,  1.99s/it]
#
#
#  94%|█████████▎| 468/500 [12:37<00:58,  1.81s/it]
#
#
#  94%|█████████▍| 469/500 [12:38<00:51,  1.66s/it]
#
#
#  94%|█████████▍| 470/500 [12:40<00:46,  1.56s/it]
#
#
#  94%|█████████▍| 471/500 [12:41<00:42,  1.47s/it]
#
#
#  94%|█████████▍| 472/500 [12:44<00:51,  1.84s/it]
#
#
#  95%|█████████▍| 473/500 [12:47<00:58,  2.15s/it]
#
#
#  95%|█████████▍| 474/500 [12:48<00:52,  2.02s/it]
#
#
#  95%|█████████▌| 475/500 [12:50<00:45,  1.80s/it]
#
#
#  95%|█████████▌| 476/500 [12:51<00:39,  1.66s/it]
#
#
#  95%|█████████▌| 477/500 [12:52<00:35,  1.56s/it]
#
#
#  96%|█████████▌| 478/500 [12:54<00:34,  1.56s/it]
#
#
#  96%|█████████▌| 479/500 [12:57<00:39,  1.89s/it]
#
#
#  96%|█████████▌| 480/500 [12:59<00:43,  2.16s/it]
#
#
#  96%|█████████▌| 481/500 [13:01<00:36,  1.93s/it]
#
#
#  96%|█████████▋| 482/500 [13:02<00:31,  1.75s/it]
#
#
#  97%|█████████▋| 483/500 [13:03<00:27,  1.62s/it]
#
#
#  97%|█████████▋| 484/500 [13:05<00:24,  1.52s/it]
#
#
#  97%|█████████▋| 485/500 [13:06<00:22,  1.48s/it]
#
#
#  97%|█████████▋| 486/500 [13:08<00:23,  1.66s/it]
#
#
#  97%|█████████▋| 487/500 [13:11<00:26,  2.01s/it]
#
#
#  98%|█████████▊| 488/500 [13:14<00:26,  2.23s/it]
#
#
#  98%|█████████▊| 489/500 [13:16<00:26,  2.38s/it]
#
#
#  98%|█████████▊| 490/500 [13:19<00:25,  2.54s/it]
#
#
#  98%|█████████▊| 491/500 [13:21<00:21,  2.43s/it]
#
#
#  98%|█████████▊| 492/500 [13:23<00:17,  2.17s/it]
#
#
#  99%|█████████▊| 493/500 [13:24<00:13,  1.91s/it]
#
#
#  99%|█████████▉| 494/500 [13:26<00:11,  1.97s/it]
#
#
#  99%|█████████▉| 495/500 [13:29<00:11,  2.21s/it]
#
#
#  99%|█████████▉| 496/500 [13:32<00:09,  2.34s/it]
#
#
#  99%|█████████▉| 497/500 [13:34<00:07,  2.40s/it]
#
#
# 100%|█████████▉| 498/500 [13:36<00:04,  2.10s/it]
#
#
# 100%|█████████▉| 499/500 [13:37<00:01,  1.89s/it]
#
#
# 100%|██████████| 500/500 [13:40<00:00,  1.64s/it]
# 0.968
# 0.968
# 0.068
